# %%
import gym
import numpy as np

# %%
from stable_baselines3 import PPO
from stable_baselines3.ppo.policies import MlpPolicy

# %% [markdown]
# "A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart. The pendulum starts upright, and the goal is to prevent it from falling over. A reward of +1 is provided for every timestep that the pole remains upright. The episode ends when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center." [CartPole-v1](https://gym.openai.com/envs/CartPole-v1/),
#
# [Max episode length is 500](https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py), therefore the max reward is also 500.

# %%
env = gym.make('CartPole-v1')

model = PPO(MlpPolicy, env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train the agent for 100'000 steps
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    fps             | 587      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 25           |
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0092019085 |
# |    clip_fraction        | 0.0875       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.00153      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.74         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 50.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.2        |
# |    ep_rew_mean          | 34.2        |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010377032 |
# |    clip_fraction        | 0.074       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.0878      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 37.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.7        |
# |    ep_rew_mean          | 46.7        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010377943 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 49.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.6        |
# |    ep_rew_mean          | 62.6        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010505648 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 63.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.7         |
# |    ep_rew_mean          | 78.7         |
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 6            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0077998526 |
# |    clip_fraction        | 0.0776       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.516        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 53.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.2         |
# |    ep_rew_mean          | 98.2         |
# | time/                   |              |
# |    fps                  | 443          |
# |    iterations           | 7            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0041943006 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.524        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00529     |
# |    value_loss           | 58.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 116          |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 8            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0040211687 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00374     |
# |    value_loss           | 52.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 129          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 9            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0043835314 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.17         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 25.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 150        |
# | time/                   |            |
# |    fps                  | 431        |
# |    iterations           | 10         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00657994 |
# |    clip_fraction        | 0.0526     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.583     |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.96       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00425   |
# |    value_loss           | 17.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 11           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0040845666 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00504     |
# |    value_loss           | 29.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 12          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004617541 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.407       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00847    |
# |    value_loss           | 7.67        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 206          |
# |    ep_rew_mean          | 206          |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 13           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0093525285 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 30.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 14          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004975195 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.167       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 4.07        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 15           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0053924695 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | -0.017       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0795       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 1.68         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 16           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0054247766 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | -0.0185      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0427       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 1.11         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 274        |
# |    ep_rew_mean          | 274        |
# | time/                   |            |
# |    fps                  | 422        |
# |    iterations           | 17         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00652996 |
# |    clip_fraction        | 0.0523     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.527     |
# |    explained_variance   | 0.104      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0482     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00322   |
# |    value_loss           | 0.694      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 292        |
# |    ep_rew_mean          | 292        |
# | time/                   |            |
# |    fps                  | 423        |
# |    iterations           | 18         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00733405 |
# |    clip_fraction        | 0.0499     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.518     |
# |    explained_variance   | 0.173      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0431     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00383   |
# |    value_loss           | 0.444      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 19          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005710655 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | -0.0336     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0179      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 0.282       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 327         |
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 20          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005575414 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.00579     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00939     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 0.177       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 343        |
# |    ep_rew_mean          | 343        |
# | time/                   |            |
# |    fps                  | 423        |
# |    iterations           | 21         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00305757 |
# |    clip_fraction        | 0.0185     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.538     |
# |    explained_variance   | -0.0252    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0117     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.000233  |
# |    value_loss           | 0.109      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 362          |
# |    ep_rew_mean          | 362          |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 22           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0049665244 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | -0.00448     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00556     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 0.0703       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | 376         |
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 23          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.002597312 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | -0.0206     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00932     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000664   |
# |    value_loss           | 0.0454      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 390          |
# |    ep_rew_mean          | 390          |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 24           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0057487013 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000462     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 0.0274       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 403          |
# |    ep_rew_mean          | 403          |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 25           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0022394916 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | -0.00231     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0205      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000629    |
# |    value_loss           | 0.0174       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 412         |
# |    ep_rew_mean          | 412         |
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 26          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.001530107 |
# |    clip_fraction        | 0.00835     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.506      |
# |    explained_variance   | 0.0112      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00472     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 7.36e-05    |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 420          |
# |    ep_rew_mean          | 420          |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 27           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0035549374 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | -0.024       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0102      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 0.00728      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 432          |
# |    ep_rew_mean          | 432          |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 28           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0049337987 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | -0.00707     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00655      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 0.00492      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 443          |
# |    ep_rew_mean          | 443          |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 29           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0065618916 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0.0257       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0189      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 0.00313      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 450         |
# |    ep_rew_mean          | 450         |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 30          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.003934974 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | -0.0261     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 0.00213     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | 460         |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 31          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004657435 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.517      |
# |    explained_variance   | 0.076       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0398      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | 466         |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 32          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006702083 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | -0.0269     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 0.000971    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 479        |
# |    ep_rew_mean          | 479        |
# | time/                   |            |
# |    fps                  | 419        |
# |    iterations           | 33         |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00358614 |
# |    clip_fraction        | 0.0175     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.528     |
# |    explained_variance   | -0.0352    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00896    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -3.61e-05  |
# |    value_loss           | 0.000698   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 485          |
# |    ep_rew_mean          | 485          |
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 34           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0046869144 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | -0.104       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0172      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 0.000525     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 490          |
# |    ep_rew_mean          | 490          |
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 35           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0047651147 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | -0.0734      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00411      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.000334     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | 495         |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 36          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009297544 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.522      |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00783    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 0.000243    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 37           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0067710076 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 0.0585       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000477    |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00698     |
# |    value_loss           | 0.000179     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 38          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005264706 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | -0.168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00169     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 0.00012     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 39          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005578857 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | -0.0667     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00521    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 8.34e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 40          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005377977 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | -0.141      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0154      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 6.35e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 41          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010873463 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | -0.126      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00935     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 4.63e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 42           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0056353128 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | -0.0524      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00947     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 3.62e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 43           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0035925629 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | -0.0596      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0044      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 2.14e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 44          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002641215 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | -0.117      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 2.13e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 45          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008441921 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | -0.193      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 1.27e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 46           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0068714414 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | -0.142       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00428      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 8.61e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 47           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0022821706 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | -0.366       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00225     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 6.06e-06     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 500       |
# |    ep_rew_mean          | 500       |
# | time/                   |           |
# |    fps                  | 408       |
# |    iterations           | 48        |
# |    time_elapsed         | 240       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0027141 |
# |    clip_fraction        | 0.0611    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.406    |
# |    explained_variance   | -0.343    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00925  |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.00262  |
# |    value_loss           | 4.39e-06  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 49           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0016887165 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.381       |
# |    explained_variance   | -0.256       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00435     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 3.18e-06     |
# ------------------------------------------

# %%
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Evaluate the trained agent - for info on why the is wrapped with Monitor check the evaluate_policy function
mean_reward, std_reward = evaluate_policy(model, Monitor(env), n_eval_episodes=100)
print(f"mean_reward trained agent: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward trained agent: 500.00 +/- 0.00
