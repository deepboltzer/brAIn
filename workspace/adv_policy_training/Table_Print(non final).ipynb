# %%
import numpy as np
import matplotlib.pyplot as plt



def get_color(data):
    color=[]
    for row in data:
        r=[]
        for value in row:
             r.append((0, 0.4, 1, value/100))
        color.append(r)    
    return color


title_text = 'Adv. Siege'
title_text2 = 'Victim Siege'
title_text3 = 'Unentschieden'





data =  [
            [ 2,      8,        2     ],
            [ 2,       9,        7      ],
            [ 4,      3,        3     ],
        ]

data2 = [
            [ 51,        55,       61     ],
            [ 49,       58,       64     ],
            [ 49,       70,       63     ],
        ]

data3 =  [
            [ 47,       37,       37     ],
            [ 49,       33,       32     ],
            [ 47,       27,       34     ],
        ]

data4= [
    [75, 25, 0,47,53,0],
    [3, 97, 0,1,99,0],
    [12, 88, 0,1,99,0]
]
data5= [
    [1, 99, 53,47,86,14],
    ["-", "-",25,75,"-","-"]
]

col_lables=['Adv_v1', 'Adv_v2', 'Adv_v3']
row_lables=['Vic_v1','Vic_v2','Vic_v3']

col2_lables=['Adv_W','Adv_L','Ties','Zoo_W','Zoo_L','Zoo_Ties']
row2_lables=['Vic_v1','Vic_M','Vic_D']

col3_lables=['Adv_W','Adv_L','Zoo_W','Zoo_L','Adv2_W','Adv2_L']
row3_lables=['Vic_Final','Adv2']

plt.figure(linewidth=2,
           tight_layout={'pad':1},
           #figsize=(5,3)
          )

color=get_color(data)
color2=get_color(data2)
color3=get_color(data3)
color4=get_color(data4)


"""
plt.subplot(131,title=title_text)
table=plt.table(cellText=data,
                      cellColours=color,
                      rowLabels=row_lables,
                      rowLoc='right',
                      colLabels=col_lables,
                      loc='center')


ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Hide axes border
plt.box(on=None)


plt.subplot(132,title=title_text2)
table2=plt.table(cellText=data2,
                      cellColours=color2,
                      rowLabels=row_lables,
                      rowLoc='right',
                      colLabels=col_lables,
                      loc='center')


ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Hide axes border
plt.box(on=None)


plt.subplot(133,title=title_text3)
table3=plt.table(cellText=data3,
                      cellColours=color3,
                      rowLabels=row_lables,
                      rowLoc='right',
                      colLabels=col_lables,
                      loc='center')
"""
table4=plt.table(cellText=data5,
                      rowLabels=row3_lables,
                      rowLoc='right',
                      colLabels=col3_lables,
                      loc='center')


# Hide axes
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Hide axes border
plt.box(on=None)

fig = plt.gcf()
plt.savefig('Übersicht',
            #bbox='tight',
            edgecolor=fig.get_edgecolor(),
            facecolor=fig.get_facecolor(),
            dpi=150
            )
        
plt.show()

# %% [markdown]
# ## OLD VERSION

# %%
import numpy as np
import matplotlib.pyplot as plt

#title_text = 'Adv. Siege'
#title_text = 'Victim Siege'
title_text = 'Unentschieden'

"""
data =  [
            [         'Adv_v1', 'Adv_v2', 'Adv_v3'],
            ['Vic_v1', 74,      28,        23     ],
            ['Vic_v2', 7,       16,        8      ],
            ['Vic_v3', 11,      28,        42     ],
        ]
"""
"""
data =  [
            [         'Adv_v1', 'Adv_v2', 'Adv_v3'],
            ['Vic_v1', 7,        43,       57     ],
            ['Vic_v2', 62,       24,       74     ],
            ['Vic_v3', 70,       46,       24     ],
        ]
"""


data =  [
            [         'Adv_v1', 'Adv_v2', 'Adv_v3'],
            ['Vic_v1', 19,       29,       20     ],
            ['Vic_v2', 31,       60,       18     ],
            ['Vic_v3', 19,       26,       34     ],
        ]



# Pop the headers from the data array
column_headers = data.pop(0)
row_headers = [x.pop(0) for x in data]
# Table data needs to be non-numeric text. Format the data
# while I'm at it.
cell_text = []
for row in data:
    cell_text.append([x for x in row])
# Get some lists of color specs for row and column headers
rcolors = plt.cm.BuPu(np.full(len(row_headers), 0.1))
ccolors = plt.cm.BuPu(np.full(len(column_headers), 0.1))
# Create the figure. Setting a small pad on tight_layout
# seems to better regulate white space. Sometimes experimenting
# with an explicit figsize here can produce better outcome.
plt.figure(linewidth=2,
           tight_layout={'pad':1},
           #figsize=(5,3)
          )
# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=row_headers,
                      rowColours=rcolors,
                      rowLoc='right',
                      colColours=ccolors,
                      colLabels=column_headers,
                      loc='center')
plt.suptitle(title_text)
# Scaling is the only influence we have over top and bottom cell padding.
# Make the rows taller (i.e., make cell y scale larger).
the_table.scale(1, 1.5)
# Hide axes
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Hide axes border
plt.box(on=None)
# Force the figure to update, so backends center objects correctly within the figure.
# Without plt.draw() here, the title will center on the axes and not the figure.
plt.draw()

"""
fig = plt.gcf()
plt.savefig('Ties',
            #bbox='tight',
            edgecolor=fig.get_edgecolor(),
            facecolor=fig.get_facecolor(),
            dpi=150
            )
"""
plt.show()
